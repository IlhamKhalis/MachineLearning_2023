# %% [markdown]
# <a href="https://colab.research.google.com/github/IlhamKhalis/MachineLearning_2023/blob/main/Job%20Sheet%2011%3A%20Convolutional%20Neural%20Network%20(CNN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NAMA : Muhammad Bagas Ramadhan
#
# KELAS : TI - 3G
#
# NIM : 21417120120
#
# Link GitHub : https://github.com/bagasyramadhan/MachineLearning_2023/blob/main/CNN_MachineLearning_Muhammad_Bagas_Ramadhan.ipynb

# %% [markdown]
# **Job Sheet 11: Convolutional Neural Network (CNN)**

# %% [markdown]
# **Praktikum 1**
#
#
# Klasifikasi 🐱 dan 🐶

# %% [markdown]
# Langkah 1 - Import Library

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# **Langkah 2 - Pra Pengolahan Data**
#
# Pada tahap ini kita akan sedikit melakukan manipulasi pada citra yang digunakan. Manipulasi yang dilakukan diantaranya adalah normalisasi nilai piksel, koreksi kemiringan, pembesaran (zoom), dan flip.

# %% [markdown]
# Langkah 2.1. Pra Pengolahan Data Training

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/MachLearn/dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 8010 images belonging to 2 classes.

# %% [markdown]
# Langkah 2.2. Pra Pengolahan Data Testing

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/MachLearn/dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# **Langkah 3 - Pembuatan Model CNN**

# %% [markdown]
# Langkah 3.1.  - Inisiasi Model CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# Langkah 3.2. - Pembuatan Layer Konvolusi 1

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))

# %% [markdown]
# Langkah 3.3 - Pembuatan Layer Pooling 1

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# Langkah 3.4 - Pembuatan Layer Konvolusi 2 dan Pooling 2

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# Langkah 3.5 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# Langkah 3.6 - Fully Connected Layer 1 (Input)

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# Langkah 3.7 - Fully Connected Layer 2 (Output)

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# Langkah 3.8 - Compile Model CNN

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# **Langkah 4 - Fit CNN**

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# Epoch 1/25
# 251/251 [==============================] - 1157s 5s/step - loss: 0.6774 - accuracy: 0.5607 - val_loss: 0.6129 - val_accuracy: 0.6645
# Epoch 2/25
# 251/251 [==============================] - 37s 146ms/step - loss: 0.6101 - accuracy: 0.6638 - val_loss: 0.6181 - val_accuracy: 0.6640
# Epoch 3/25
# 251/251 [==============================] - 43s 171ms/step - loss: 0.5692 - accuracy: 0.7054 - val_loss: 0.5453 - val_accuracy: 0.7330
# Epoch 4/25
# 251/251 [==============================] - 38s 151ms/step - loss: 0.5391 - accuracy: 0.7280 - val_loss: 0.5103 - val_accuracy: 0.7435
# Epoch 5/25
# 251/251 [==============================] - 43s 170ms/step - loss: 0.5115 - accuracy: 0.7446 - val_loss: 0.4973 - val_accuracy: 0.7675
# Epoch 6/25
# 251/251 [==============================] - 39s 157ms/step - loss: 0.4808 - accuracy: 0.7677 - val_loss: 0.5000 - val_accuracy: 0.7655
# Epoch 7/25
# 251/251 [==============================] - 39s 155ms/step - loss: 0.4638 - accuracy: 0.7853 - val_loss: 0.5092 - val_accuracy: 0.7630
# Epoch 8/25
# 251/251 [==============================] - 38s 153ms/step - loss: 0.4540 - accuracy: 0.7797 - val_loss: 0.4602 - val_accuracy: 0.7970
# Epoch 9/25
# 251/251 [==============================] - 38s 151ms/step - loss: 0.4361 - accuracy: 0.7949 - val_loss: 0.4558 - val_accuracy: 0.8055
# Epoch 10/25
# 251/251 [==============================] - 38s 151ms/step - loss: 0.4092 - accuracy: 0.8082 - val_loss: 0.4814 - val_accuracy: 0.7880
# Epoch 11/25
# 251/251 [==============================] - 36s 145ms/step - loss: 0.4018 - accuracy: 0.8152 - val_loss: 0.4691 - val_accuracy: 0.7875
# Epoch 12/25
# 251/251 [==============================] - 37s 146ms/step - loss: 0.3820 - accuracy: 0.8293 - val_loss: 0.4753 - val_accuracy: 0.7850
# Epoch 13/25
# 251/251 [==============================] - 37s 147ms/step - loss: 0.3690 - accuracy: 0.8282 - val_loss: 0.4466 - val_accuracy: 0.8065
# Epoch 14/25
# 251/251 [==============================] - 36s 144ms/step - loss: 0.3474 - accuracy: 0.8476 - val_loss: 0.4657 - val_accuracy: 0.7980
# Epoch 15/25
# 251/251 [==============================] - 37s 146ms/step - loss: 0.3416 - accuracy: 0.8479 - val_loss: 0.4495 - val_accuracy: 0.8040
# Epoch 16/25
# 251/251 [==============================] - 38s 151ms/step - loss: 0.3212 - accuracy: 0.8589 - val_loss: 0.4536 - val_accuracy: 0.7995
# Epoch 17/25
# 251/251 [==============================] - 39s 154ms/step - loss: 0.3127 - accuracy: 0.8654 - val_loss: 0.4644 - val_accuracy: 0.8020
# Epoch 18/25
# 251/251 [==============================] - 35s 141ms/step - loss: 0.3020 - accuracy: 0.8702 - val_loss: 0.4682 - val_accuracy: 0.7970
# Epoch 19/25
# 251/251 [==============================] - 36s 143ms/step - loss: 0.2769 - accuracy: 0.8794 - val_loss: 0.4812 - val_accuracy: 0.8060
# Epoch 20/25
# 251/251 [==============================] - 37s 146ms/step - loss: 0.2729 - accuracy: 0.8840 - val_loss: 0.5514 - val_accuracy: 0.7865
# Epoch 21/25
# 251/251 [==============================] - 36s 142ms/step - loss: 0.2544 - accuracy: 0.8928 - val_loss: 0.5601 - val_accuracy: 0.7830
# Epoch 22/25
# 251/251 [==============================] - 36s 144ms/step - loss: 0.2383 - accuracy: 0.9040 - val_loss: 0.5410 - val_accuracy: 0.8000
# Epoch 23/25
# 251/251 [==============================] - 36s 143ms/step - loss: 0.2228 - accuracy: 0.9104 - val_loss: 0.4954 - val_accuracy: 0.8115
# Epoch 24/25
# 251/251 [==============================] - 36s 142ms/step - loss: 0.2157 - accuracy: 0.9097 - val_loss: 0.6065 - val_accuracy: 0.7875
# Epoch 25/25
# 251/251 [==============================] - 36s 144ms/step - loss: 0.2117 - accuracy: 0.9140 - val_loss: 0.5680 - val_accuracy: 0.7970

# %% [markdown]
# **Langkah 5 - Prediksi dengan 1 Citra**
#
# Pada langkah ini, kita akan mencoba melakukan prediksi pada 1 citra anjing dan kucing.

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('/content/drive/MyDrive/MachLearn/dataset/single_prediction/cat_or_dog_1.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
# Out:
# 1/1 [==============================] - 0s 191ms/step

# %% [markdown]
# **Praktikum 2**
#
# Klasifikasi Multi-label dengan Data CIFAT

# %% [markdown]
# Langkah 1 - Load Library

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %% [markdown]
# Langkah 2 - Unduh Dataset CIFAR

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 10s 0us/step

# %% [markdown]
# Langkah 3 - Verifikasi Data

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
       'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
  plt.subplot(5,5,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(train_images[i])
  # The CIFAR labels happen to be arrays,
  # which is why you need the extra index
  plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %% [markdown]
# **Langkah 4 - Buat Model CNN**

# %% [markdown]
# Langkah 4.1. - Buat Layer Konvolusi

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

# %% [markdown]
# Langkah 4.2. - Cek Arsitektur Konvolusi

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 30, 30, 32)        896
#
#  max_pooling2d_2 (MaxPoolin  (None, 15, 15, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_3 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 4, 4, 64)          36928
#
# =================================================================
# Total params: 56320 (220.00 KB)
# Trainable params: 56320 (220.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Langkah 4.3. - Tambahkan Layer Fully Connected

# %%
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))

# %% [markdown]
# Langkah 4.4. - Cek Arsitektur Model CNN

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 30, 30, 32)        896
#
#  max_pooling2d_2 (MaxPoolin  (None, 15, 15, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_3 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 4, 4, 64)          36928
#
#  flatten_1 (Flatten)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 64)                65600
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 122570 (478.79 KB)
# Trainable params: 122570 (478.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Langkah 4.5. - Compile Model CNN

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# **Langkah 5 - Fit Model**

# %%
history = model.fit(train_images, train_labels, epochs=10,
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 10s 5ms/step - loss: 1.5113 - accuracy: 0.4491 - val_loss: 1.2351 - val_accuracy: 0.5586
# Epoch 2/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.1480 - accuracy: 0.5919 - val_loss: 1.0652 - val_accuracy: 0.6214
# Epoch 3/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.9936 - accuracy: 0.6514 - val_loss: 0.9819 - val_accuracy: 0.6578
# Epoch 4/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.8938 - accuracy: 0.6874 - val_loss: 0.8951 - val_accuracy: 0.6905
# Epoch 5/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8152 - accuracy: 0.7149 - val_loss: 0.9504 - val_accuracy: 0.6764
# Epoch 6/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7620 - accuracy: 0.7356 - val_loss: 0.8560 - val_accuracy: 0.7045
# Epoch 7/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7058 - accuracy: 0.7515 - val_loss: 0.8462 - val_accuracy: 0.7104
# Epoch 8/10
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.6651 - accuracy: 0.7675 - val_loss: 0.8728 - val_accuracy: 0.7004
# Epoch 9/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6263 - accuracy: 0.7784 - val_loss: 0.8593 - val_accuracy: 0.7139
# Epoch 10/10
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5900 - accuracy: 0.7930 - val_loss: 0.9189 - val_accuracy: 0.6982

# %% [markdown]
# **Langkah 6 - Evaluasi Model**

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.9189 - accuracy: 0.6982 - 1s/epoch - 4ms/step

# %% [markdown]
# **Langkah 7 - Cetak Hasil Akurasi**

# %%
print(test_acc)
# Out:
# 0.698199987411499

# %% [markdown]
# **TUGAS**
#
# 1. Modifikasi model CNN pada praktikum 2 sehingga didapatkan akurasi testing lebih dari 80%.

# %%
from tensorflow.keras.datasets import cifar10
import numpy as np
import pandas as pd
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import utils
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Dropout, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from PIL import Image

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
print('Training set shape:', X_train.shape)
print('Test set shape:', X_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 6s 0us/step
# Training set shape: (50000, 32, 32, 3)
# Test set shape: (10000, 32, 32, 3)

# %%
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
def cnn_model():
    model = Sequential()
    # First Conv layer
    model.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-4), input_shape=(32,32,3)))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.3))

    # Second Conv layer
    model.add(Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-4)))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.3))

    # Third, fourth, fifth convolution layer
    model.add(Conv2D(filters=512, kernel_size=(3,3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-4)))
    model.add(Conv2D(filters=512, kernel_size=(3,3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-4)))
    model.add(Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-4)))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.3))

    # Fully Connected layers
    model.add(Flatten())

    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(10, activation='softmax'))

    model.summary()
    return model

# %%
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False
)
datagen.fit(X_train)

# %%
model = cnn_model()
model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.0003),
    metrics=['accuracy']
)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 128)       3584
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 128)       0
#  D)
#
#  dropout (Dropout)           (None, 16, 16, 128)       0
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 256)       295168
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 256)         0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 256)         0
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 512)         1180160
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 512)         2359808
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         1179904
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 256)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 256)         0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 512)               2097664
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 7281802 (27.78 MB)
# Trainable params: 7281802 (27.78 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(
    datagen.flow(X_train, y_train, batch_size=64),
    steps_per_epoch=len(X_train) // 64,
    epochs=50,
    validation_data=(X_valid, y_valid),
    verbose=1
)
# Out:
# Epoch 1/50
# 625/625 [==============================] - 51s 59ms/step - loss: 2.1575 - accuracy: 0.1992 - val_loss: 1.9122 - val_accuracy: 0.2713
# Epoch 2/50
# 625/625 [==============================] - 36s 57ms/step - loss: 1.7307 - accuracy: 0.3530 - val_loss: 1.5046 - val_accuracy: 0.4546
# Epoch 3/50
# 625/625 [==============================] - 40s 63ms/step - loss: 1.5293 - accuracy: 0.4456 - val_loss: 1.3513 - val_accuracy: 0.5114
# Epoch 4/50
# 625/625 [==============================] - 36s 57ms/step - loss: 1.4118 - accuracy: 0.5066 - val_loss: 1.2074 - val_accuracy: 0.5737
# Epoch 5/50
# 625/625 [==============================] - 35s 57ms/step - loss: 1.3126 - accuracy: 0.5507 - val_loss: 1.0827 - val_accuracy: 0.6256
# Epoch 6/50
# 625/625 [==============================] - 34s 55ms/step - loss: 1.2337 - accuracy: 0.5854 - val_loss: 1.0165 - val_accuracy: 0.6486
# Epoch 7/50
# 625/625 [==============================] - 36s 57ms/step - loss: 1.1623 - accuracy: 0.6129 - val_loss: 0.9833 - val_accuracy: 0.6653
# Epoch 8/50
# 625/625 [==============================] - 34s 55ms/step - loss: 1.1204 - accuracy: 0.6329 - val_loss: 0.9680 - val_accuracy: 0.6674
# Epoch 9/50
# 625/625 [==============================] - 34s 55ms/step - loss: 1.0761 - accuracy: 0.6464 - val_loss: 0.8888 - val_accuracy: 0.7031
# Epoch 10/50
# 625/625 [==============================] - 35s 57ms/step - loss: 1.0445 - accuracy: 0.6629 - val_loss: 0.9258 - val_accuracy: 0.6925
# Epoch 11/50
# 625/625 [==============================] - 34s 53ms/step - loss: 1.0056 - accuracy: 0.6817 - val_loss: 0.9450 - val_accuracy: 0.7015
# Epoch 12/50
# 625/625 [==============================] - 34s 54ms/step - loss: 0.9808 - accuracy: 0.6900 - val_loss: 0.8600 - val_accuracy: 0.7218
# Epoch 13/50
# 625/625 [==============================] - 35s 56ms/step - loss: 0.9559 - accuracy: 0.7016 - val_loss: 0.8508 - val_accuracy: 0.7261
# Epoch 14/50
# 625/625 [==============================] - 34s 55ms/step - loss: 0.9267 - accuracy: 0.7118 - val_loss: 0.7949 - val_accuracy: 0.7475
# Epoch 15/50
# 625/625 [==============================] - 34s 54ms/step - loss: 0.9127 - accuracy: 0.7188 - val_loss: 0.8006 - val_accuracy: 0.7508
# Epoch 16/50
# 625/625 [==============================] - 35s 56ms/step - loss: 0.8834 - accuracy: 0.7286 - val_loss: 0.7238 - val_accuracy: 0.7740
# Epoch 17/50
# 625/625 [==============================] - 34s 54ms/step - loss: 0.8652 - accuracy: 0.7384 - val_loss: 0.7556 - val_accuracy: 0.7683
# Epoch 18/50
# 625/625 [==============================] - 35s 55ms/step - loss: 0.8465 - accuracy: 0.7476 - val_loss: 0.7074 - val_accuracy: 0.7869
# Epoch 19/50
# 625/625 [==============================] - 34s 54ms/step - loss: 0.8317 - accuracy: 0.7538 - val_loss: 0.7410 - val_accuracy: 0.7724
# Epoch 20/50
# 625/625 [==============================] - 34s 54ms/step - loss: 0.8201 - accuracy: 0.7590 - val_loss: 0.6952 - val_accuracy: 0.7904
# Epoch 21/50
# 625/625 [==============================] - 35s 56ms/step - loss: 0.8002 - accuracy: 0.7656 - val_loss: 0.7304 - val_accuracy: 0.7814
# Epoch 22/50
# 625/625 [==============================] - 35s 56ms/step - loss: 0.7819 - accuracy: 0.7730 - val_loss: 0.6554 - val_accuracy: 0.8094
# Epoch 23/50
# 625/625 [==============================] - 35s 57ms/step - loss: 0.7830 - accuracy: 0.7732 - val_loss: 0.7318 - val_accuracy: 0.7869
# Epoch 24/50
# 625/625 [==============================] - 35s 56ms/step - loss: 0.7664 - accuracy: 0.7810 - val_loss: 0.6864 - val_accuracy: 0.8004
# Epoch 25/50
# 625/625 [==============================] - 36s 57ms/step - loss: 0.7543 - accuracy: 0.7879 - val_loss: 0.6253 - val_accuracy: 0.8280
# Epoch 26/50
# 625/625 [==============================] - 35s 56ms/step - loss: 0.7446 - accuracy: 0.7897 - val_loss: 0.6899 - val_accuracy: 0.8037
# Epoch 27/50
# 625/625 [==============================] - 34s 55ms/step - loss: 0.7380 - accuracy: 0.7917 - val_loss: 0.7280 - val_accuracy: 0.7939
# Epoch 28/50
# 625/625 [==============================] - 35s 55ms/step - loss: 0.7301 - accuracy: 0.7970 - val_loss: 0.6519 - val_accuracy: 0.8150
# Epoch 29/50
# 625/625 [==============================] - 35s 57ms/step - loss: 0.7182 - accuracy: 0.7998 - val_loss: 0.7354 - val_accuracy: 0.7891
# Epoch 30/50
# 625/625 [==============================] - 35s 56ms/step - loss: 0.7126 - accuracy: 0.8044 - val_loss: 0.6341 - val_accuracy: 0.8239
# Epoch 31/50
# 625/625 [==============================] - 35s 57ms/step - loss: 0.6975 - accuracy: 0.8099 - val_loss: 0.6621 - val_accuracy: 0.8187
# Epoch 32/50
# 625/625 [==============================] - 35s 55ms/step - loss: 0.6955 - accuracy: 0.8111 - val_loss: 0.6419 - val_accuracy: 0.8272
# Epoch 33/50
# 625/625 [==============================] - 34s 55ms/step - loss: 0.6964 - accuracy: 0.8107 - val_loss: 0.7867 - val_accuracy: 0.7761
# Epoch 34/50
# 625/625 [==============================] - 34s 55ms/step - loss: 0.6834 - accuracy: 0.8156 - val_loss: 0.6592 - val_accuracy: 0.8183
# Epoch 35/50
# 625/625 [==============================] - 36s 57ms/step - loss: 0.6777 - accuracy: 0.8187 - val_loss: 0.7233 - val_accuracy: 0.8009
# Epoch 36/50
# 625/625 [==============================] - 35s 57ms/step - loss: 0.6715 - accuracy: 0.8233 - val_loss: 0.6357 - val_accuracy: 0.8294
# Epoch 37/50
# 625/625 [==============================] - 36s 57ms/step - loss: 0.6738 - accuracy: 0.8200 - val_loss: 0.6923 - val_accuracy: 0.8120
# Epoch 38/50
# 625/625 [==============================] - 36s 57ms/step - loss: 0.6699 - accuracy: 0.8229 - val_loss: 0.6560 - val_accuracy: 0.8228
# Epoch 39/50
# 625/625 [==============================] - 35s 56ms/step - loss: 0.6601 - accuracy: 0.8242 - val_loss: 0.6898 - val_accuracy: 0.8128
# Epoch 40/50
# 625/625 [==============================] - 34s 55ms/step - loss: 0.6594 - accuracy: 0.8266 - val_loss: 0.6350 - val_accuracy: 0.8349
# Epoch 41/50
# 625/625 [==============================] - 35s 56ms/step - loss: 0.6490 - accuracy: 0.8330 - val_loss: 0.6250 - val_accuracy: 0.8398
# Epoch 42/50
# 625/625 [==============================] - 35s 55ms/step - loss: 0.6557 - accuracy: 0.8297 - val_loss: 0.6386 - val_accuracy: 0.8330
# Epoch 43/50
# 625/625 [==============================] - 34s 55ms/step - loss: 0.6463 - accuracy: 0.8352 - val_loss: 0.6581 - val_accuracy: 0.8306
# Epoch 44/50
# 625/625 [==============================] - 34s 55ms/step - loss: 0.6468 - accuracy: 0.8339 - val_loss: 0.6035 - val_accuracy: 0.8460
# Epoch 45/50
# 625/625 [==============================] - 35s 56ms/step - loss: 0.6301 - accuracy: 0.8389 - val_loss: 0.6045 - val_accuracy: 0.8478
# Epoch 46/50
# 625/625 [==============================] - 34s 54ms/step - loss: 0.6341 - accuracy: 0.8410 - val_loss: 0.6572 - val_accuracy: 0.8371
# Epoch 47/50
# 625/625 [==============================] - 35s 56ms/step - loss: 0.6362 - accuracy: 0.8398 - val_loss: 0.6427 - val_accuracy: 0.8366
# Epoch 48/50
# 625/625 [==============================] - 34s 55ms/step - loss: 0.6361 - accuracy: 0.8381 - val_loss: 0.6236 - val_accuracy: 0.8441
# Epoch 49/50
# 625/625 [==============================] - 34s 54ms/step - loss: 0.6273 - accuracy: 0.8410 - val_loss: 0.6315 - val_accuracy: 0.8402
# Epoch 50/50
# 625/625 [==============================] - 35s 56ms/step - loss: 0.6210 - accuracy: 0.8462 - val_loss: 0.6258 - val_accuracy: 0.8455

# %%
scores = model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6728 - accuracy: 0.8372

# %%
pd.DataFrame(history.history).plot()
# Out:
# <Axes: >

# %%
scores = model.evaluate(X_test, y_test)
pred = model.predict(X_test)
labels = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']
y_pred = np.argmax(pred, axis=1)
y_true = np.argmax(y_test, axis=1)
errors = y_pred - y_true != 0
print(classification_report(y_true, y_pred))
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6728 - accuracy: 0.8372
# 313/313 [==============================] - 2s 7ms/step
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84      1000
#            1       0.91      0.94      0.92      1000
#            2       0.89      0.68      0.77      1000
#            3       0.77      0.64      0.70      1000
#            4       0.87      0.76      0.82      1000
#            5       0.78      0.78      0.78      1000
#            6       0.78      0.94      0.85      1000
#            7       0.83      0.91      0.87      1000
#            8       0.90      0.91      0.91      1000
#            9       0.84      0.94      0.89      1000
#
#     accuracy                           0.84     10000
#    macro avg       0.84      0.84      0.83     10000
# weighted avg       0.84      0.84      0.83     10000

# %%
fig, axes = plt.subplots(5, 5, figsize=(12,12))
axes = axes.ravel()
for i in np.arange(25):
    axes[i].imshow(X_test[i])
    axes[i].set_title('True: %s \nPredict: %s' % (labels[y_true[i]], labels[y_pred[i]]))
    axes[i].axis('off')
    plt.subplots_adjust(wspace=1)

# %% [markdown]
# 2. Buatlah model CNN untuk klasifikasi dataset MNIST.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist

# Memuat dataset MNIST
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
# Normalisasi gambar ke rentang [0, 1]
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
# Perbaikan: Mengimpor to_categorical dari tensorflow.keras.utils
from tensorflow.keras.utils import to_categorical

# Mengonversi label ke format one-hot encoding
train_labels = to_categorical(train_labels, num_classes=10)
test_labels = to_categorical(test_labels, num_classes=10)

# %%
# Menampilkan informasi tentang dataset
print("Jumlah data latihan:", len(train_images))
print("Jumlah data pengujian:", len(test_images))
print("Ukuran gambar:", train_images[0].shape)
# Out:
# Jumlah data latihan: 60000
# Jumlah data pengujian: 10000
# Ukuran gambar: (28, 28)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Membangun model
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28,28,1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

# %%
# Mengompilasi model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Menampilkan ringkasan model
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_3 (MaxPoolin  (None, 13, 13, 32)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_4 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 1600)              0
#
#  dense_4 (Dense)             (None, 128)               204928
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 64)                8256
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 232650 (908.79 KB)
# Trainable params: 232650 (908.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Melatih model
history = model.fit(train_images, train_labels, epochs=10, batch_size=128, verbose=2, validation_split=0.3)
# Out:
# Epoch 1/10
# 329/329 - 5s - loss: 0.3729 - accuracy: 0.8845 - val_loss: 0.0910 - val_accuracy: 0.9721 - 5s/epoch - 14ms/step
# Epoch 2/10
# 329/329 - 2s - loss: 0.0961 - accuracy: 0.9710 - val_loss: 0.0635 - val_accuracy: 0.9812 - 2s/epoch - 7ms/step
# Epoch 3/10
# 329/329 - 2s - loss: 0.0677 - accuracy: 0.9794 - val_loss: 0.0501 - val_accuracy: 0.9855 - 2s/epoch - 6ms/step
# Epoch 4/10
# 329/329 - 2s - loss: 0.0504 - accuracy: 0.9846 - val_loss: 0.0477 - val_accuracy: 0.9859 - 2s/epoch - 5ms/step
# Epoch 5/10
# 329/329 - 2s - loss: 0.0450 - accuracy: 0.9860 - val_loss: 0.0425 - val_accuracy: 0.9876 - 2s/epoch - 6ms/step
# Epoch 6/10
# 329/329 - 2s - loss: 0.0348 - accuracy: 0.9892 - val_loss: 0.0395 - val_accuracy: 0.9885 - 2s/epoch - 5ms/step
# Epoch 7/10
# 329/329 - 2s - loss: 0.0287 - accuracy: 0.9913 - val_loss: 0.0613 - val_accuracy: 0.9837 - 2s/epoch - 6ms/step
# Epoch 8/10
# 329/329 - 2s - loss: 0.0277 - accuracy: 0.9920 - val_loss: 0.0451 - val_accuracy: 0.9879 - 2s/epoch - 5ms/step
# Epoch 9/10
# 329/329 - 2s - loss: 0.0217 - accuracy: 0.9934 - val_loss: 0.0458 - val_accuracy: 0.9872 - 2s/epoch - 7ms/step
# Epoch 10/10
# 329/329 - 2s - loss: 0.0199 - accuracy: 0.9935 - val_loss: 0.0424 - val_accuracy: 0.9902 - 2s/epoch - 7ms/step

# %%
import matplotlib.pyplot as plt

# Plot sejarah pelatihan
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Akurasi Pelatihan')
plt.plot(history.history['val_accuracy'], label='Akurasi Validasi')
plt.legend(loc='lower right')
plt.title('Akurasi Pelatihan dan Validasi')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Loss Pelatihan')
plt.plot(history.history['val_loss'], label='Loss Validasi')
plt.legend(loc='upper right')
plt.title('Loss Pelatihan dan Validasi')

plt.show()

# %%
# Evaluasi model pada kumpulan data uji
validation_loss, validation_accuracy = model.evaluate(test_images, test_labels, verbose=False)
print("Loss Validasi:", validation_loss)
print("Akurasi Validasi:", validation_accuracy)
# Out:
# Loss Validasi: 0.03159790486097336
# Akurasi Validasi: 0.9915000200271606

# %%
# Menghasilkan nilai prediksi pada kumpulan data uji
y_pred_enc = model.predict(test_images)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %%
# Mendekode nilai prediksi
y_pred = [np.argmax(i) for i in y_pred_enc]

# %%
# Menampilkan laporan klasifikasi
print(classification_report(np.argmax(test_labels, axis=1), y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       980
#            1       0.99      1.00      1.00      1135
#            2       0.99      1.00      0.99      1032
#            3       0.99      0.99      0.99      1010
#            4       0.99      0.99      0.99       982
#            5       0.99      0.98      0.99       892
#            6       0.99      0.99      0.99       958
#            7       0.99      0.99      0.99      1028
#            8       0.99      0.99      0.99       974
#            9       0.99      0.99      0.99      1009
#
#     accuracy                           0.99     10000
#    macro avg       0.99      0.99      0.99     10000
# weighted avg       0.99      0.99      0.99     10000

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Membuat matriks konfusi dan menampilkannya dengan heatmap
fig, ax = plt.subplots(figsize=(7, 7))
sns.heatmap(confusion_matrix(np.argmax(test_labels, axis=1), y_pred), annot=True, cbar=False, fmt='1d', cmap='Blues', ax=ax)
ax.set_title('Matriks Konfusi', loc='left', fontsize=16)
ax.set_xlabel('Prediksi')
ax.set_ylabel('Aktual')
# Out:
# Text(58.222222222222214, 0.5, 'Aktual')

# %%
# Menampilkan target yang diprediksi pada setiap gambar
# (label di atas gambar adalah label yang diprediksi)
plt.figure(figsize=(14, 8))
for ind, row in enumerate(test_images[:15]):
    plt.subplot(3, 5, ind+1)
    plt.title(y_pred[ind])
    img = row.reshape(28, 28)
    plt.axis('off')
    plt.imshow(img, cmap='cividis')
